# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
import math

# %%
if(True):
    df_cleaned = pd.read_csv('/data/ortho/AllPatients.csv',  sep= ';')
    df_cleaned['clavicula_x_dif'] = np.absolute(df_cleaned['clavicula_l_x'] - df_cleaned['clavicula_r_x'])
    df_cleaned['clavicula_y_dif'] = np.absolute(df_cleaned['clavicula_l_y'] - df_cleaned['clavicula_r_y'])
    df_cleaned['clavicula_z_dif'] = np.absolute(df_cleaned['clavicula_l_z'] - df_cleaned['clavicula_r_z'])

    df_cleaned['scapula_x_dif'] = np.absolute(df_cleaned['scapula_l_x'] - df_cleaned['scapula_r_x'])
    df_cleaned['scapula_y_dif'] = np.absolute(df_cleaned['scapula_l_y'] - df_cleaned['scapula_r_y'])
    df_cleaned['scapula_z_dif'] = np.absolute(df_cleaned['scapula_l_z'] - df_cleaned['scapula_r_z'])

    df_cleaned['humerus_x_dif'] = np.absolute(df_cleaned['humerus_l_x'] - df_cleaned['humerus_r_x'])
    df_cleaned['humerus_y_dif'] = np.absolute(df_cleaned['humerus_l_y'] - df_cleaned['humerus_r_y'])
    df_cleaned['humerus_z_dif'] = np.absolute(df_cleaned['humerus_l_z'] - df_cleaned['humerus_r_z'])

    param = [ \
              'humerus_l_x', 'humerus_l_y', 'humerus_l_z', 'humerus_r_x', 'humerus_r_y', 'humerus_r_z', \
              'clavicula_l_x', 'clavicula_l_y', 'clavicula_l_z', 'clavicula_r_x', 'clavicula_r_y', 'clavicula_r_z', \
              'scapula_l_x', 'scapula_l_y', 'scapula_l_z', 'scapula_r_x', 'scapula_r_y', 'scapula_r_z', \
              'clavicula_x_dif','clavicula_y_dif','clavicula_z_dif', \
              'scapula_x_dif','scapula_y_dif','scapula_z_dif', \
              'humerus_x_dif', 'humerus_y_dif', 'humerus_z_dif'
             ]

    Oorsprongdata,rest = df_cleaned['Oorsprong'].str.split(".").str
    df_cleaned['Categorie'],df_cleaned['pat'],df_cleaned['meting'],df_cleaned['oef'] = Oorsprongdata.str.split("_").str
    df_cleaned['Categorie'] = [ int(x[3:]) for x in df_cleaned['Categorie']] 
    df_cleaned['meting'] = [ int(x[6:]) for x in df_cleaned['meting']] 
    df_cleaned['oef'] = [ int(x[3:]) for x in df_cleaned['oef']] 
    df_cleaned['pat'] = [ int(x[3:]) for x in df_cleaned['pat']] 
    # geef elke patient een uniek nummer
    df_cleaned['pat'] = df_cleaned['Categorie']*1000+df_cleaned['pat']

    df = df_cleaned[df_cleaned.index % 5 == 0]

    yValueColumn = 'Categorie'

    X_param = np.matrix(df_cleaned[param])
    y = df_cleaned[yValueColumn]

# %%
if(False):
    df_cleaned = pd.read_csv('all_predictions.csv', sep=';')
    param = ['Cat1', 'Cat2', 'Cat3', 'Cat4']
    df_cleaned[['Cat1', 'Cat2', 'Cat3', 'Cat4']] = df_cleaned[['Cat1', 'Cat2', 'Cat3', 'Cat4']].stack().str.replace(',','.').unstack()
    yValueColumn = 'groundtruth'
    X_param = np.matrix(df_cleaned[param])
    y = df_cleaned[yValueColumn]
    print(df_cleaned.head())

# %%
# Use SKLearn.linear_model
# model_param = LinearRegression()
model_param = MLPClassifier(hidden_layer_sizes=(50,40,50), alpha=0.0003, solver='sgd', verbose=10,  random_state=21,tol=0.00001)
model_param.fit(X_param, y)
# Out:
# Iteration 1, loss = 0.84355834
# Iteration 2, loss = 0.58034364
# Iteration 3, loss = 0.48963880
# Iteration 4, loss = 0.42073532
# Iteration 5, loss = 0.37079195
# Iteration 6, loss = 0.33225463
# Iteration 7, loss = 0.29999683
# Iteration 8, loss = 0.27204695
# Iteration 9, loss = 0.24867275
# Iteration 10, loss = 0.23057254
# Iteration 11, loss = 0.21638086
# Iteration 12, loss = 0.20246342
# Iteration 13, loss = 0.19003363
# Iteration 14, loss = 0.17847158
# Iteration 15, loss = 0.16890714
# Iteration 16, loss = 0.15903966
# Iteration 17, loss = 0.15031576
# Iteration 18, loss = 0.14330103
# Iteration 19, loss = 0.13472325
# Iteration 20, loss = 0.12862014
# Iteration 21, loss = 0.12347899
# Iteration 22, loss = 0.11777978
# Iteration 23, loss = 0.11279508
# Iteration 24, loss = 0.10765507
# Iteration 25, loss = 0.10420313
# Iteration 26, loss = 0.09988354
# Iteration 27, loss = 0.09474366
# Iteration 28, loss = 0.09197168
# Iteration 29, loss = 0.08929198
# Iteration 30, loss = 0.08618440
# Iteration 31, loss = 0.08302056
# Iteration 32, loss = 0.08160684
# Iteration 33, loss = 0.07777801
# Iteration 34, loss = 0.07524901
# Iteration 35, loss = 0.07302527
# Iteration 36, loss = 0.07186695
# Iteration 37, loss = 0.06891915
# Iteration 38, loss = 0.06773910
# Iteration 39, loss = 0.06578453
# Iteration 40, loss = 0.06457564
# Iteration 41, loss = 0.06266563
# Iteration 42, loss = 0.06119823
# Iteration 43, loss = 0.06003857
# Iteration 44, loss = 0.05859749
# Iteration 45, loss = 0.05701811
# Iteration 46, loss = 0.05508347
# Iteration 47, loss = 0.05422456
# Iteration 48, loss = 0.05225113
# Iteration 49, loss = 0.05158948
# Iteration 50, loss = 0.05117570
# Iteration 51, loss = 0.05004246
# Iteration 52, loss = 0.05011657
# Iteration 53, loss = 0.04868865
# Iteration 54, loss = 0.04717750
# Iteration 55, loss = 0.04656628
# Iteration 56, loss = 0.04517769
# Iteration 57, loss = 0.04395178
# Iteration 58, loss = 0.04387982
# Iteration 59, loss = 0.04302942
# Iteration 60, loss = 0.04349822
# Iteration 61, loss = 0.04272696
# Iteration 62, loss = 0.04065703
# Iteration 63, loss = 0.04037731
# Iteration 64, loss = 0.03919870
# Iteration 65, loss = 0.03860184
# Iteration 66, loss = 0.03725471
# Iteration 67, loss = 0.03769688
# Iteration 68, loss = 0.03601239
# Iteration 69, loss = 0.03634192
# Iteration 70, loss = 0.03561810
# Iteration 71, loss = 0.03572305
# Iteration 72, loss = 0.03565259
# Iteration 73, loss = 0.03316056
# Iteration 74, loss = 0.03396531
# Iteration 75, loss = 0.03271298
# Iteration 76, loss = 0.03354662
# Iteration 77, loss = 0.03333704
# Iteration 78, loss = 0.03082354
# Iteration 79, loss = 0.03064954
# Iteration 80, loss = 0.03092248
# Iteration 81, loss = 0.02990796
# Iteration 82, loss = 0.03157573
# Iteration 83, loss = 0.02959165
# Iteration 84, loss = 0.02790257
# Iteration 85, loss = 0.02807357
# Iteration 86, loss = 0.02751772
# Iteration 87, loss = 0.02766174
# Iteration 88, loss = 0.02739805
# Iteration 89, loss = 0.02815831
# Iteration 90, loss = 0.02683556
# Iteration 91, loss = 0.02783026
# Iteration 92, loss = 0.02540142
# Iteration 93, loss = 0.02590613
# Iteration 94, loss = 0.02634171
# Iteration 95, loss = 0.02408061
# Iteration 96, loss = 0.02470293
# Iteration 97, loss = 0.02574367
# Iteration 98, loss = 0.02406829
# Iteration 99, loss = 0.02327842
# Iteration 100, loss = 0.02297060
# Iteration 101, loss = 0.02442509
# Iteration 102, loss = 0.02282991
# Iteration 103, loss = 0.02270862
# Iteration 104, loss = 0.02196785
# Iteration 105, loss = 0.02236285
# Iteration 106, loss = 0.02328820
# Iteration 107, loss = 0.02065435
# Iteration 108, loss = 0.02315945
# Iteration 109, loss = 0.02232653
# Iteration 110, loss = 0.02074168
# Iteration 111, loss = 0.02058790
# Iteration 112, loss = 0.02057290
# Iteration 113, loss = 0.02030958
# Iteration 114, loss = 0.02194290
# Iteration 115, loss = 0.02147135
# Iteration 116, loss = 0.02069361
# Iteration 117, loss = 0.01923458
# Iteration 118, loss = 0.02066774
# Iteration 119, loss = 0.01864625
# Iteration 120, loss = 0.01905775
# Iteration 121, loss = 0.01938963
# Iteration 122, loss = 0.01766458
# Iteration 123, loss = 0.01753362
# Iteration 124, loss = 0.01684199
# Iteration 125, loss = 0.01920240
# Iteration 126, loss = 0.01780685
# Iteration 127, loss = 0.01712130
# Iteration 128, loss = 0.01885986
# Iteration 129, loss = 0.01758217
# Iteration 130, loss = 0.01695149
# Iteration 131, loss = 0.01775880
# Iteration 132, loss = 0.01655118
# Iteration 133, loss = 0.01756860
# Iteration 134, loss = 0.01511744
# Iteration 135, loss = 0.01566489
# Iteration 136, loss = 0.01744485
# Iteration 137, loss = 0.01767769
# Iteration 138, loss = 0.01807779
# Iteration 139, loss = 0.01583471
# Iteration 140, loss = 0.01554638
# Iteration 141, loss = 0.01490255
# Iteration 142, loss = 0.01610036
# Iteration 143, loss = 0.01681992
# Iteration 144, loss = 0.01722366
# Iteration 145, loss = 0.01531640
# Iteration 146, loss = 0.01523172
# Iteration 147, loss = 0.01718904
# Iteration 148, loss = 0.01758076
# Iteration 149, loss = 0.01462017
# Iteration 150, loss = 0.01420619
# Iteration 151, loss = 0.01477550
# Iteration 152, loss = 0.01410522
# Iteration 153, loss = 0.01491714
# Iteration 154, loss = 0.01416506
# Iteration 155, loss = 0.01607494
# Iteration 156, loss = 0.01721323
# Iteration 157, loss = 0.01407645
# Iteration 158, loss = 0.01522126
# Iteration 159, loss = 0.01623841
# Iteration 160, loss = 0.01334651
# Iteration 161, loss = 0.01369259
# Iteration 162, loss = 0.01458495
# Iteration 163, loss = 0.01353546
# Iteration 164, loss = 0.01473870
# Iteration 165, loss = 0.01233872
# Iteration 166, loss = 0.01434352
# Iteration 167, loss = 0.01138220
# Iteration 168, loss = 0.01260477
# Iteration 169, loss = 0.01453288
# Iteration 170, loss = 0.01434104
# Iteration 171, loss = 0.01329448
# Iteration 172, loss = 0.01258581
# Iteration 173, loss = 0.01252608
# Iteration 174, loss = 0.01308344
# Iteration 175, loss = 0.01576107
# Iteration 176, loss = 0.01343086
# Iteration 177, loss = 0.01229398
# Iteration 178, loss = 0.01071422
# Iteration 179, loss = 0.01288150
# Iteration 180, loss = 0.01769699
# Iteration 181, loss = 0.01293879
# Iteration 182, loss = 0.01259391
# Iteration 183, loss = 0.01054113
# Iteration 184, loss = 0.01407934
# Iteration 185, loss = 0.01254738
# Iteration 186, loss = 0.01007549
# Iteration 187, loss = 0.01179757
# Iteration 188, loss = 0.01065229
# Iteration 189, loss = 0.01149034
# Iteration 190, loss = 0.01034919
# Iteration 191, loss = 0.01031396
# Iteration 192, loss = 0.01113933
# Iteration 193, loss = 0.00920357
# Iteration 194, loss = 0.00980237
# Iteration 195, loss = 0.01054994
# Iteration 196, loss = 0.01008639
# Iteration 197, loss = 0.01501721
# Iteration 198, loss = 0.01226021
# Iteration 199, loss = 0.01248295
# Iteration 200, loss = 0.01140359
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.0003, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 40, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=21, shuffle=True, solver='sgd', tol=1e-05,
#        validation_fraction=0.1, verbose=10, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error

y_pred = model_param.predict(X_param)
mean_squared_error(y_pred, y)
# Out:
# 0.0058854066413518355

# %%
# kolom met voorspelling toevoegen aan data)
df_cleaned['predict'] = y_pred
df_cleaned['predict_round'] = [int(round(i)) if i <4 and i > 1 else 4 if i > 4 else 1 for i in y_pred]

# %%
## maak tabel (df4) met per patient het aantal sampels dat true en false gelabeld wordt.

# aantal false tellen
df2 = df_cleaned.groupby(['pat','predict_round']).size().to_frame('countF').reset_index()
df2.set_index(['pat', 'predict_round'], inplace=True)
df2 = df2.unstack(-1)
df2 = df2.join(df_cleaned[['pat',yValueColumn]].drop_duplicates(subset=['pat', yValueColumn]).set_index('pat'))

def CalculatePerc(cat, CountF1, CountF2, CountF3, CountF4):
    Count = [CountF1, CountF2, CountF3, CountF4]
    perc = 100*Count[cat-1]/np.nansum(Count)
    if(math.isnan(perc)):
        perc = 0
    return perc
#  = 100*df4['countT'] / (df4['countT'] + df4['countF'])
df2['percentage'] = np.vectorize(CalculatePerc)(df2[yValueColumn], df2['countF', 1],df2['countF', 2],df2['countF', 3],df2['countF', 4])
df2.sort_values(by=['percentage'],ascending=False)
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('countF', 4)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a64bfd977924> in <module>
#      14     return perc
#      15 #  = 100*df4['countT'] / (df4['countT'] + df4['countF'])
# ---> 16 df2['percentage'] = np.vectorize(CalculatePerc)(df2[yValueColumn], df2['countF', 1],df2['countF', 2],df2['countF', 3],df2['countF', 4])
#      17 df2.sort_values(by=['percentage'],ascending=False)
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('countF', 4)

# %%
ParamCheck = pd.DataFrame()
ParamCheck['Params'] = param
ParamCheck['Theta'] = list(model_param.coef_)
ParamCheck['Absolute'] = np.absolute(list(ParamCheck['Theta']))
ParamCheck = ParamCheck.sort_values(by=['Absolute'])
print(ParamCheck)

# %%
rownum = 16
print(df_cleaned.iloc[rownum])
ypredict = model_param.predict_proba(df_cleaned[param].iloc[[rownum]])
for i in ypredict[0]:
    print(format(i, '.20f'))
# Out:
# Unnamed: 0                                  16
# thorax_r_x                             2.98579
# thorax_r_y                             1.81774
# thorax_r_z                           -0.902788
# clavicula_r_x                         -38.0663
# clavicula_r_y                          11.7811
# clavicula_r_z                          -5.3143
# scapula_r_x                            15.6572
# scapula_r_y                           -2.82482
# scapula_r_z                           -12.0968
# humerus_r_x                           -45.6684
# humerus_r_y                            46.4151
# humerus_r_z                            62.9918
# ellebooghoek_r                         427.718
# 13                                           0
# 14                                           0
# thorax_l_x                             2.98579
# thorax_l_y                            -1.81774
# thorax_l_z                            0.902788
# clavicula_l_x                         -23.6929
# clavicula_l_y                          8.56488
# clavicula_l_z                         -9.04059
# scapula_l_x                            23.6731
# scapula_l_y                            -3.4359
# scapula_l_z                             -11.93
# humerus_l_x                           -42.3432
# humerus_l_y                            39.4625
# humerus_l_z                            51.3757
# ellebooghoek_l                         399.543
# 28                                           0
# 29                                           0
# Oorsprong          Cat3_pat38_meting2_oef6.csv
# clavicula_x_dif                        14.3734
# clavicula_y_dif                        3.21627
# clavicula_z_dif                         3.7263
# scapula_x_dif                          8.01585
# scapula_y_dif                         0.611073
# scapula_z_dif                         0.166809
# humerus_x_dif                          3.32521
# humerus_y_dif                          6.95265
# humerus_z_dif                          11.6161
# Categorie                                    3
# pat                                       3038
# meting                                       2
# oef                                          6
# predict                                      3
# predict_round                                3
# Name: 16, dtype: object
# 0.00000000000000000003
# 0.00000000311668317885
# 0.99999999688331686620
# 0.00000000000000000000

# %%
ypredict
# Out:
# array([[2.76021504e-20, 3.11668318e-09, 9.99999997e-01, 3.51560958e-23]])
