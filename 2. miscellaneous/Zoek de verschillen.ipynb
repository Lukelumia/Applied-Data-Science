# %%
import numpy as np
import pandas as pd
from os import listdir
import matplotlib.pyplot as plt

# %%
def HeaderMaker(PatientFile):
    df_cleaned = pd.read_csv('/data/ortho/' + PatientFile, header=None)

    df_cleaned = df_cleaned.rename(columns={0: "thorax_r_x", 1: "thorax_r_y", 2: "thorax_r_z"})
    df_cleaned = df_cleaned.rename(columns={3: "clavicula_r_x", 4: "clavicula_r_y", 5: "clavicula_r_z"})
    df_cleaned = df_cleaned.rename(columns={6: "scapula_r_x", 7: "scapula_r_y", 8: "scapula_r_z"})
    df_cleaned = df_cleaned.rename(columns={9: "humerus_r_x", 10: "humerus_r_y", 11: "humerus_r_z"})
    df_cleaned = df_cleaned.rename(columns={12: "ellebooghoek_r"})
    df_cleaned = df_cleaned.rename(columns={15: "thorax_l_x", 16: "thorax_l_y", 17: "thorax_l_z"})
    df_cleaned = df_cleaned.rename(columns={18: "clavicula_l_x", 19: "clavicula_l_y", 20: "clavicula_l_z"})
    df_cleaned = df_cleaned.rename(columns={21: "scapula_l_x", 22: "scapula_l_y", 23: "scapula_l_z"})
    df_cleaned = df_cleaned.rename(columns={24: "humerus_l_x", 25: "humerus_l_y", 26: "humerus_l_z"})
    df_cleaned = df_cleaned.rename(columns={27: "ellebooghoek_l"})
    
    return df_cleaned

def VisualizeItems(items, x, y, z):
    for i in items:
        fig = plt.figure()

        splitted = i.split('.')[0].split('_')
        Cat = splitted[0]
        pat = splitted[1]
        meting = splitted[2]
        oef = splitted[3]

        data = HeaderMaker(i)

        xlist = data[x]
        ylist = data[y]
        zlist = data[z]

        plt.title('oefening: %s' % (oef))
        plt.ylim((-180,180))
        plt.plot(xlist, color = 'red')
        plt.plot(ylist, color = 'blue')
        plt.plot(zlist, color = 'green')
    plt.tight_layout()  
    plt.show()

# %%
cat4_oef10 = ['Cat4_pat11_meting1_oef10.csv',
        'Cat4_pat12_meting1_oef10.csv',
        'Cat4_pat14_meting1_oef10.csv',
        'Cat4_pat15_meting1_oef10.csv',
        'Cat4_pat17_meting1_oef10.csv',
        'Cat4_pat20_meting1_oef10.csv',
        'Cat4_pat23_meting1_oef10.csv',
        'Cat4_pat24_meting1_oef10.csv',
        'Cat4_pat6_meting1_oef10.csv',
        'Cat4_pat11_meting2_oef10.csv',
        'Cat4_pat12_meting2_oef10.csv',
        'Cat4_pat14_meting2_oef10.csv',
        'Cat4_pat15_meting2_oef10.csv',
        'Cat4_pat17_meting2_oef10.csv',
        'Cat4_pat20_meting2_oef10.csv',
        'Cat4_pat23_meting2_oef10.csv',
        'Cat4_pat24_meting2_oef10.csv',
        'Cat4_pat6_meting2_oef10.csv'
        ]

cat4_oef11 = [
        'Cat4_pat12_meting1_oef11.csv',
        'Cat4_pat14_meting1_oef11.csv',
        'Cat4_pat17_meting1_oef11.csv',
        'Cat4_pat20_meting1_oef11.csv',
        'Cat4_pat23_meting1_oef11.csv',
        'Cat4_pat24_meting1_oef11.csv',
        'Cat4_pat6_meting1_oef11.csv',
        'Cat4_pat11_meting2_oef11.csv',
        'Cat4_pat12_meting2_oef11.csv',
        'Cat4_pat14_meting2_oef11.csv',
        'Cat4_pat15_meting2_oef11.csv',
        'Cat4_pat17_meting2_oef11.csv',
        'Cat4_pat20_meting2_oef11.csv',
        'Cat4_pat23_meting2_oef11.csv',
        'Cat4_pat24_meting2_oef11.csv',
        'Cat4_pat6_meting2_oef11.csv',

]



# x, y, z = ('scapula_r_x', 'scapula_r_y', 'scapula_r_z')
x, y, z = ("scapula_r_x", "scapula_r_y", "scapula_r_z")
# x, y, z = ("humerus_r_x", "humerus_r_y", "humerus_r_z")
# x, y, z = ("ellebooghoek_r", "ellebooghoek_l", "ellebooghoek_r")

VisualizeItems(cat4_oef10, x, y, z)
VisualizeItems(cat4_oef11, x, y, z)
